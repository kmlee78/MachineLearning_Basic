# %%
from sklearn.datasets import load_boston
# 다항 속성을 만들어 주는 툴
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import pandas as pd

# %%
boston_dataset = load_boston()

# %%
boston_dataset.data.shape
# Out:
# (506, 13)

# %%
# 몇 차의 가설함수를 만들것 인지 설정하고 변수에 저장 
polynomial_transformer = PolynomialFeatures(2)

# %%
# 가지고 있는 데이터를 이렇게 fit_transform에 넘겨주면 자동으로 다항회귀 속성들을 만들어 준다
polynomial_data = polynomial_transformer.fit_transform(boston_dataset.data)

# %%
# 크기를 확인해보면 열의 크기가 13 -> 105 로 늘어난 것을 확인할 수 있다
polynomial_data.shape
# Out:
# (506, 105)

# %%
# 새로 만들어진 속성들의 이름을 확인하고 싶으면 get_feature_names 메소드 안에 기존 속성 이름들을 넘겨준다 
polynomial_feature_names = polynomial_transformer.get_feature_names(boston_dataset.feature_names)

# %%
# 다항 속성들을 가진 데이터와 그 속성 이름들을 저장해 놓은 변수로 입력 변수 행렬 X를 만든다
X = pd.DataFrame(polynomial_data, columns=polynomial_feature_names)
X
# Out:
#        1     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  ...  \
# 0    1.0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  ...
# 1    1.0  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  ...
# 2    1.0  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  ...
# 3    1.0  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  ...
# 4    1.0  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  ...
# ..   ...      ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  1.0  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  ...
# 502  1.0  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  ...
# 503  1.0  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  ...
# 504  1.0  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  ...
# 505  1.0  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  ...
#
# ...

# %%
# 이후로는 전에 했던 선형회귀랑 같은 방식으로 하면 됨
y = pd.DataFrame(boston_dataset.target, columns=['MEDV'])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=5)
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [[-2.55720149e-07 -5.09146959e+00 -1.65753983e-01 -5.97358604e+00
#    2.43179261e+01  1.65180559e+02  2.19910116e+01  1.03167123e+00
#   -5.66895775e+00  3.22443249e+00 -1.10055942e-02  5.35127787e+00
#   -4.81524409e-02  7.53109325e-01  2.16774682e-03  2.69938772e-01
#    5.87901385e-01  2.41731932e+00 -2.52413196e-02  8.92859572e-02
#   -5.18832420e-03 -5.77807152e-02  3.55602049e-01 -3.86092282e-02
#    5.43572101e-01 -3.18134359e-04  2.40035425e-02 -7.48850219e-04
#   -7.16133310e-03 -1.06886010e-01 -1.27782609e+00  2.50137719e-02
#    1.14111417e-04 -1.25254119e-02 -4.68024813e-03  6.05725185e-04
#   -8.57873132e-03  1.85030053e-03 -4.64730601e-03  3.08484808e-02
#   -2.09065897e-01  1.30035723e+00  3.13497405e-01  6.72540164e-04
#    7.51823883e-02 -7.38014889e-03  4.23364348e-04 -6.72155117e-03
#    6.42107774e-03 -5.32275093e-03  2.43179260e+01 -1.84845896e+01
#   -6.89090796e+00  3.60375828e-02  3.05451225e+00 -4.09746374e-01
# ...

# %%
y_test_prediction = model.predict(X_test)
mean_squared_error(y_test, y_test_prediction) ** 0.5
# Out:
# 3.1965276510797094
