# %%
"""절대 모멘텀 전략"""

import pandas as pd
import numpy as np
import datetime
import FinanceDataReader as fdr

df = fdr.DataReader('AAPL', '1996')
price_df = df.loc[:,['Close']].copy()
price_df.rename(columns={'Close' : 'Adj Close'}, inplace=True)
price_df['Date'] = price_df.index

price_df.head()
# Out:
#             Adj Close       Date
# Date
# 1996-01-02       0.29 1996-01-02
# 1996-01-03       0.29 1996-01-03
# 1996-01-04       0.28 1996-01-04
# 1996-01-05       0.31 1996-01-05
# 1996-01-08       0.31 1996-01-08

# %%
# 월말 데이터 추가
price_df['STD_YM'] = price_df['Date'].map(lambda x : datetime.datetime.strftime(x, '%Y-%m'))
price_df = price_df[price_df['Date'] > '2010-03-30']
price_df.head()
# Out:
#             Adj Close       Date   STD_YM
# Date
# 2010-03-31       8.39 2010-03-31  2010-03
# 2010-04-01       8.43 2010-04-01  2010-04
# 2010-04-05       8.52 2010-04-05  2010-04
# 2010-04-06       8.55 2010-04-06  2010-04
# 2010-04-07       8.59 2010-04-07  2010-04

# %%
# 월말 종가 데이터프레임
month_list = price_df['STD_YM'].unique()
month_last_df = pd.DataFrame()
for m in month_list:
    month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD_YM'] == m].index[-1], : ])

month_last_df.set_index(['Date'], inplace=True)
month_last_df.head()
# Out:
#             Adj Close   STD_YM
# Date
# 2010-03-31       8.39  2010-03
# 2010-04-30       9.32  2010-04
# 2010-05-28       9.17  2010-05
# 2010-06-30       8.98  2010-06
# 2010-07-30       9.19  2010-07

# %%
# 1개월 전 말일자 종가, 12개월 전 말일자 종가 가져오기
month_last_df['BF_1M_Adj Close'] = month_last_df['Adj Close'].shift(1)
month_last_df['BF_12M_Adj Close'] = month_last_df['Adj Close'].shift(12)
month_last_df.fillna(0, inplace=True)
month_last_df.head(15)
# Out:
#             Adj Close   STD_YM  BF_1M_Adj Close  BF_12M_Adj Close
# Date
# 2010-03-31       8.39  2010-03             0.00              0.00
# 2010-04-30       9.32  2010-04             8.39              0.00
# 2010-05-28       9.17  2010-05             9.32              0.00
# 2010-06-30       8.98  2010-06             9.17              0.00
# 2010-07-30       9.19  2010-07             8.98              0.00
# 2010-08-31       8.68  2010-08             9.19              0.00
# 2010-09-30      10.13  2010-09             8.68              0.00
# 2010-10-29      10.75  2010-10            10.13              0.00
# 2010-11-30      11.11  2010-11            10.75              0.00
# 2010-12-31      11.52  2010-12            11.11              0.00
# 2011-01-31      12.12  2011-01            11.52              0.00
# 2011-02-28      12.61  2011-02            12.12              0.00
# 2011-03-31      12.45  2011-03            12.61              8.39
# 2011-04-29      12.50  2011-04            12.45              9.32
# 2011-05-31      12.42  2011-05            12.50              9.17

# %%
# 포지션 기록
book = price_df.copy()
book.set_index(['Date'], inplace=True)
book['trade'] = ''
book.head()
# Out:
#             Adj Close   STD_YM trade
# Date
# 2010-03-31       8.39  2010-03
# 2010-04-01       8.43  2010-04
# 2010-04-05       8.52  2010-04
# 2010-04-06       8.55  2010-04
# 2010-04-07       8.59  2010-04

# %%
# 모멘텀이 발생하면 매수 신호가 발생하도록 함
ticker = 'SPY'
for x in month_last_df.index:
    signal = ''
    flag = False
    momentum = month_last_df.loc[x, 'BF_1M_Adj Close'] / month_last_df.loc[x, 'BF_12M_Adj Close'] - 1
    if momentum > 0.0 and momentum != np.inf and momentum != -np.inf:
        signal = 'buy ' + ticker
        flag = True
    book.loc[x:, 'trade'] = signal
    print('날짜: ', x, ' 모멘텀 인덱스: ', momentum, ' flag: ', flag, ' signal: ', signal)
# Out:
# <ipython-input-6-8ad1ce970292>:6: RuntimeWarning: invalid value encountered in double_scalars
#   momentum = month_last_df.loc[x, 'BF_1M_Adj Close'] / month_last_df.loc[x, 'BF_12M_Adj Close'] - 1
# <ipython-input-6-8ad1ce970292>:6: RuntimeWarning: divide by zero encountered in double_scalars
#   momentum = month_last_df.loc[x, 'BF_1M_Adj Close'] / month_last_df.loc[x, 'BF_12M_Adj Close'] - 1
# 날짜:  2010-03-31 00:00:00  모멘텀 인덱스:  nan  flag:  False  signal:
# 날짜:  2010-04-30 00:00:00  모멘텀 인덱스:  inf  flag:  False  signal:
# 날짜:  2010-05-28 00:00:00  모멘텀 인덱스:  inf  flag:  False  signal:
# 날짜:  2010-06-30 00:00:00  모멘텀 인덱스:  inf  flag:  False  signal:
# 날짜:  2010-07-30 00:00:00  모멘텀 인덱스:  inf  flag:  False  signal:
# 날짜:  2010-08-31 00:00:00  모멘텀 인덱스:  inf  flag:  False  signal:
# 날짜:  2010-09-30 00:00:00  모멘텀 인덱스:  inf  flag:  False  signal:
# 날짜:  2010-10-29 00:00:00  모멘텀 인덱스:  inf  flag:  False  signal:
# 날짜:  2010-11-30 00:00:00  모멘텀 인덱스:  inf  flag:  False  signal:
# 날짜:  2010-12-31 00:00:00  모멘텀 인덱스:  inf  flag:  False  signal:
# 날짜:  2011-01-31 00:00:00  모멘텀 인덱스:  inf  flag:  False  signal:
# 날짜:  2011-02-28 00:00:00  모멘텀 인덱스:  inf  flag:  False  signal:
# 날짜:  2011-03-31 00:00:00  모멘텀 인덱스:  0.5029797377830749  flag:  True  signal:  buy SPY
# 날짜:  2011-04-29 00:00:00  모멘텀 인덱스:  0.3358369098712446  flag:  True  signal:  buy SPY
# 날짜:  2011-05-31 00:00:00  모멘텀 인덱스:  0.36314067611777534  flag:  True  signal:  buy SPY
# 날짜:  2011-06-30 00:00:00  모멘텀 인덱스:  0.3830734966592426  flag:  True  signal:  buy SPY
# 날짜:  2011-07-29 00:00:00  모멘텀 인덱스:  0.3046789989118608  flag:  True  signal:  buy SPY
# 날짜:  2011-08-31 00:00:00  모멘텀 인덱스:  0.6071428571428572  flag:  True  signal:  buy SPY
# 날짜:  2011-09-30 00:00:00  모멘텀 인덱스:  0.3563672260612043  flag:  True  signal:  buy SPY
# 날짜:  2011-10-31 00:00:00  모멘텀 인덱스:  0.26697674418604644  flag:  True  signal:  buy SPY
# 날짜:  2011-11-30 00:00:00  모멘텀 인덱스:  0.3015301530153016  flag:  True  signal:  buy SPY
# 날짜:  2011-12-30 00:00:00  모멘텀 인덱스:  0.18489583333333348  flag:  True  signal:  buy SPY
# 날짜:  2012-01-31 00:00:00  모멘텀 인덱스:  0.19306930693069324  flag:  True  signal:  buy SPY
# 날짜:  2012-02-29 00:00:00  모멘텀 인덱스:  0.2926249008723236  flag:  True  signal:  buy SPY
# 날짜:  2012-03-30 00:00:00  모멘텀 인덱스:  0.555823293172691  flag:  True  signal:  buy SPY
# 날짜:  2012-04-30 00:00:00  모멘텀 인덱스:  0.7128000000000001  flag:  True  signal:  buy SPY
# 날짜:  2012-05-31 00:00:00  모멘텀 인덱스:  0.6795491143317229  flag:  True  signal:  buy SPY
# 날짜:  2012-06-29 00:00:00  모멘텀 인덱스:  0.720600500417014  flag:  True  signal:  buy SPY
# 날짜:  2012-07-31 00:00:00  모멘텀 인덱스:  0.49534050179211464  flag:  True  signal:  buy SPY
# 날짜:  2012-08-31 00:00:00  모멘텀 인덱스:  0.5873362445414847  flag:  True  signal:  buy SPY
# 날짜:  2012-09-28 00:00:00  모멘텀 인덱스:  0.7444933920704848  flag:  True  signal:  buy SPY
# 날짜:  2012-10-31 00:00:00  모멘텀 인덱스:  0.6479944674965419  flag:  True  signal:  buy SPY
# 날짜:  2012-11-30 00:00:00  모멘텀 인덱스:  0.5575091575091575  flag:  True  signal:  buy SPY
# 날짜:  2012-12-31 00:00:00  모멘텀 인덱스:  0.44536652835407997  flag:  True  signal:  buy SPY
# 날짜:  2013-01-31 00:00:00  모멘텀 인덱스:  0.1662576687116566  flag:  True  signal:  buy SPY
# 날짜:  2013-02-28 00:00:00  모멘텀 인덱스:  -0.16004130098089842  flag:  False  signal:
# 날짜:  2013-03-28 00:00:00  모멘텀 인덱스:  -0.2638953759925269  flag:  False  signal:
# 날짜:  2013-04-30 00:00:00  모멘텀 인덱스:  -0.2420901246404602  flag:  False  signal:
# 날짜:  2013-05-31 00:00:00  모멘텀 인덱스:  -0.2336403296170625  flag:  False  signal:
# 날짜:  2013-06-28 00:00:00  모멘텀 인덱스:  -0.2301054650047939  flag:  False  signal:
# 날짜:  2013-07-31 00:00:00  모멘텀 인덱스:  -0.3507565337001375  flag:  False  signal:
# 날짜:  2013-08-30 00:00:00  모멘텀 인덱스:  -0.31986531986531985  flag:  False  signal:
# 날짜:  2013-09-30 00:00:00  모멘텀 인덱스:  -0.2698279479647503  flag:  False  signal:
# 날짜:  2013-10-31 00:00:00  모멘텀 인덱스:  -0.19896519285042336  flag:  False  signal:
# 날짜:  2013-11-29 00:00:00  모멘텀 인덱스:  -0.10669856459330129  flag:  False  signal:
# 날짜:  2013-12-31 00:00:00  모멘텀 인덱스:  0.044713308784849914  flag:  True  signal:  buy SPY
# 날짜:  2014-01-31 00:00:00  모멘텀 인덱스:  0.2317148125384143  flag:  True  signal:  buy SPY
# 날짜:  2014-02-28 00:00:00  모멘텀 인덱스:  0.13451776649746194  flag:  True  signal:  buy SPY
# 날짜:  2014-03-31 00:00:00  모멘텀 인덱스:  0.18848829854522453  flag:  True  signal:  buy SPY
# 날짜:  2014-04-30 00:00:00  모멘텀 인덱스:  0.2125237191650855  flag:  True  signal:  buy SPY
# 날짜:  2014-05-30 00:00:00  모멘텀 인덱스:  0.3119551681195518  flag:  True  signal:  buy SPY
# 날짜:  2014-06-30 00:00:00  모멘텀 인덱스:  0.5967514124293785  flag:  True  signal:  buy SPY
# 날짜:  2014-07-31 00:00:00  모멘텀 인덱스:  0.4375  flag:  True  signal:  buy SPY
# 날짜:  2014-08-29 00:00:00  모멘텀 인덱스:  0.37356321839080464  flag:  True  signal:  buy SPY
# 날짜:  2014-09-30 00:00:00  모멘텀 인덱스:  0.5044039929536113  flag:  True  signal:  buy SPY
# 날짜:  2014-10-31 00:00:00  모멘텀 인덱스:  0.34922335297268337  flag:  True  signal:  buy SPY
# 날짜:  2014-11-28 00:00:00  모멘텀 인덱스:  0.3595166163141994  flag:  True  signal:  buy SPY
# 날짜:  2014-12-31 00:00:00  모멘텀 인덱스:  0.4835329341317367  flag:  True  signal:  buy SPY
# 날짜:  2015-01-30 00:00:00  모멘텀 인덱스:  0.5430648769574944  flag:  True  signal:  buy SPY
# 날짜:  2015-02-27 00:00:00  모멘텀 인덱스:  0.5588078765300692  flag:  True  signal:  buy SPY
# 날짜:  2015-03-31 00:00:00  모멘텀 인덱스:  0.6755346896191963  flag:  True  signal:  buy SPY
# 날짜:  2015-04-30 00:00:00  모멘텀 인덱스:  0.47650688182249645  flag:  True  signal:  buy SPY
# 날짜:  2015-05-29 00:00:00  모멘텀 인덱스:  0.38390092879256965  flag:  True  signal:  buy SPY
# 날짜:  2015-06-30 00:00:00  모멘텀 인덱스:  0.4020662935858803  flag:  True  signal:  buy SPY
# 날짜:  2015-07-31 00:00:00  모멘텀 인덱스:  0.3121338912133891  flag:  True  signal:  buy SPY
# 날짜:  2015-08-31 00:00:00  모멘텀 인덱스:  0.18345042935206868  flag:  True  signal:  buy SPY
# 날짜:  2015-09-30 00:00:00  모멘텀 인덱스:  0.11909487892020643  flag:  True  signal:  buy SPY
# 날짜:  2015-10-30 00:00:00  모멘텀 인덱스:  0.02111111111111108  flag:  True  signal:  buy SPY
# 날짜:  2015-11-30 00:00:00  모멘텀 인덱스:  0.005045408678102881  flag:  True  signal:  buy SPY
# 날짜:  2015-12-31 00:00:00  모멘텀 인덱스:  0.07176513229430959  flag:  True  signal:  buy SPY
# 날짜:  2016-01-29 00:00:00  모멘텀 인덱스:  -0.10139979515192898  flag:  False  signal:
# 날짜:  2016-02-29 00:00:00  모멘텀 인덱스:  -0.24221668742216684  flag:  False  signal:
# 날짜:  2016-03-31 00:00:00  모멘텀 인덱스:  -0.2230793956927033  flag:  False  signal:
# 날짜:  2016-04-29 00:00:00  모멘텀 인덱스:  -0.12911473314157873  flag:  False  signal:
# 날짜:  2016-05-31 00:00:00  모멘텀 인덱스:  -0.2806263432606694  flag:  False  signal:
# 날짜:  2016-06-30 00:00:00  모멘텀 인덱스:  -0.20408163265306123  flag:  False  signal:
# 날짜:  2016-07-29 00:00:00  모멘텀 인덱스:  -0.2117414248021109  flag:  False  signal:
# 날짜:  2016-08-31 00:00:00  모멘텀 인덱스:  -0.0759134444838595  flag:  False  signal:
# 날짜:  2016-09-30 00:00:00  모멘텀 인덱스:  -0.0380848748639826  flag:  False  signal:
# 날짜:  2016-10-31 00:00:00  모멘텀 인덱스:  -0.054216867469879415  flag:  False  signal:
# 날짜:  2016-11-30 00:00:00  모멘텀 인덱스:  -0.0399053094352384  flag:  False  signal:
# 날짜:  2016-12-30 00:00:00  모멘텀 인덱스:  0.04977203647416406  flag:  True  signal:  buy SPY
# 날짜:  2017-01-31 00:00:00  모멘텀 인덱스:  0.18940016433853746  flag:  True  signal:  buy SPY
# 날짜:  2017-02-28 00:00:00  모멘텀 인덱스:  0.2552751344642117  flag:  True  signal:  buy SPY
# 날짜:  2017-03-31 00:00:00  모멘텀 인덱스:  0.25688073394495414  flag:  True  signal:  buy SPY
# 날짜:  2017-04-28 00:00:00  모멘텀 인덱스:  0.5326504481434058  flag:  True  signal:  buy SPY
# 날짜:  2017-05-31 00:00:00  모멘텀 인덱스:  0.4387019230769229  flag:  True  signal:  buy SPY
# 날짜:  2017-06-30 00:00:00  모멘텀 인덱스:  0.5979079497907949  flag:  True  signal:  buy SPY
# 날짜:  2017-07-31 00:00:00  모멘텀 인덱스:  0.38234165067178494  flag:  True  signal:  buy SPY
# 날짜:  2017-08-31 00:00:00  모멘텀 인덱스:  0.4019607843137254  flag:  True  signal:  buy SPY
# 날짜:  2017-09-29 00:00:00  모멘텀 인덱스:  0.4508138711960368  flag:  True  signal:  buy SPY
# 날짜:  2017-10-31 00:00:00  모멘텀 인덱스:  0.35716801690736166  flag:  True  signal:  buy SPY
# 날짜:  2017-11-30 00:00:00  모멘텀 인덱스:  0.5294969236337315  flag:  True  signal:  buy SPY
# 날짜:  2017-12-29 00:00:00  모멘텀 인덱스:  0.4839378238341969  flag:  True  signal:  buy SPY
# 날짜:  2018-01-31 00:00:00  모멘텀 인덱스:  0.39452867501648003  flag:  True  signal:  buy SPY
# 날짜:  2018-02-28 00:00:00  모멘텀 인덱스:  0.2221897810218978  flag:  True  signal:  buy SPY
# 날짜:  2018-03-29 00:00:00  모멘텀 인덱스:  0.24004455583402962  flag:  True  signal:  buy SPY
# 날짜:  2018-04-30 00:00:00  모멘텀 인덱스:  0.16819827346143157  flag:  True  signal:  buy SPY
# 날짜:  2018-05-31 00:00:00  모멘텀 인덱스:  0.08169677926158703  flag:  True  signal:  buy SPY
# 날짜:  2018-06-29 00:00:00  모멘텀 인덱스:  0.2974173840599834  flag:  True  signal:  buy SPY
# 날짜:  2018-07-31 00:00:00  모멘텀 인덱스:  0.2447552447552448  flag:  True  signal:  buy SPY
# 날짜:  2018-08-31 00:00:00  모멘텀 인덱스:  0.1602439024390243  flag:  True  signal:  buy SPY
# 날짜:  2018-09-28 00:00:00  모멘텀 인덱스:  0.47703088502465607  flag:  True  signal:  buy SPY
# 날짜:  2018-10-31 00:00:00  모멘텀 인덱스:  0.3355418835778514  flag:  True  signal:  buy SPY
# 날짜:  2018-11-30 00:00:00  모멘텀 인덱스:  0.2737430167597765  flag:  True  signal:  buy SPY
# 날짜:  2018-12-31 00:00:00  모멘텀 인덱스:  0.05530607421413358  flag:  True  signal:  buy SPY
# 날짜:  2019-01-31 00:00:00  모멘텀 인덱스:  -0.05781175346392742  flag:  False  signal:
# 날짜:  2019-02-28 00:00:00  모멘텀 인덱스:  -0.06557377049180335  flag:  False  signal:
# 날짜:  2019-03-29 00:00:00  모멘텀 인덱스:  0.03194278903456493  flag:  True  signal:  buy SPY
# 날짜:  2019-04-30 00:00:00  모멘텀 인덱스:  0.14960058097313  flag:  True  signal:  buy SPY
# 날짜:  2019-05-31 00:00:00  모멘텀 인덱스:  0.0738441780821919  flag:  True  signal:  buy SPY
# 날짜:  2019-06-28 00:00:00  모멘텀 인덱스:  -0.05423509075194466  flag:  False  signal:
# 날짜:  2019-07-31 00:00:00  모멘텀 인덱스:  0.04015135589657337  flag:  True  signal:  buy SPY
# 날짜:  2019-08-30 00:00:00  모멘텀 인덱스:  -0.06413635564927078  flag:  False  signal:
# 날짜:  2019-09-30 00:00:00  모멘텀 인덱스:  -0.07530120481927716  flag:  False  signal:
# 날짜:  2019-10-31 00:00:00  모멘텀 인덱스:  0.023209064327485374  flag:  True  signal:  buy SPY
# 날짜:  2019-11-29 00:00:00  모멘텀 인덱스:  0.39283314669652847  flag:  True  signal:  buy SPY
# 날짜:  2019-12-31 00:00:00  모멘텀 인덱스:  0.6939655172413794  flag:  True  signal:  buy SPY
# 날짜:  2020-01-31 00:00:00  모멘텀 인덱스:  0.7642393655371305  flag:  True  signal:  buy SPY
# 날짜:  2020-02-28 00:00:00  모멘텀 인덱스:  0.7874797874797874  flag:  True  signal:  buy SPY
# 날짜:  2020-03-31 00:00:00  모멘텀 인덱스:  0.4390397978521794  flag:  True  signal:  buy SPY
# 날짜:  2020-04-30 00:00:00  모멘텀 인덱스:  0.26709188758222036  flag:  True  signal:  buy SPY
# 날짜:  2020-05-29 00:00:00  모멘텀 인덱스:  0.678090015992689  flag:  True  signal:  buy SPY
# 날짜:  2020-06-30 00:00:00  모멘텀 인덱스:  0.6065076798706548  flag:  True  signal:  buy SPY
# 날짜:  2020-07-31 00:00:00  모멘텀 인덱스:  0.7123544874202028  flag:  True  signal:  buy SPY
# 날짜:  2020-08-31 00:00:00  모멘텀 인덱스:  1.0360222264801688  flag:  True  signal:  buy SPY
# 날짜:  2020-09-30 00:00:00  모멘텀 인덱스:  1.304697267369173  flag:  True  signal:  buy SPY
# 날짜:  2020-10-30 00:00:00  모멘텀 인덱스:  0.8621964946132821  flag:  True  signal:  buy SPY
# 날짜:  2020-11-30 00:00:00  모멘텀 인덱스:  0.6293967968866936  flag:  True  signal:  buy SPY
# 날짜:  2020-12-31 00:00:00  모멘텀 인덱스:  0.6217136629886937  flag:  True  signal:  buy SPY
# 날짜:  2021-01-29 00:00:00  모멘텀 인덱스:  0.7147841819591627  flag:  True  signal:  buy SPY
# 날짜:  2021-02-26 00:00:00  모멘텀 인덱스:  0.9309335674568335  flag:  True  signal:  buy SPY
# 날짜:  2021-03-09 00:00:00  모멘텀 인덱스:  0.9075035394053799  flag:  True  signal:  buy SPY

# %%
# 전략 수익률 -> 평균 회귀 전략할 때와 거의 비슷함!
def returns(book , ticker):
    rtn = 1.0
    book['return'] = 1
    buy = 0.0
    sell = 0.0
    
    for i in book.index:
        if book.loc[i, 'trade'] == 'buy ' + ticker and book.shift(1).loc[i,'trade'] == '':
            buy = book.loc[i, 'Adj Close']
            print('진입일: ', i, ' 진입가격: ', buy)
        elif book.loc[i, 'trade'] == 'buy ' + ticker and book.shift(1).loc[i, 'trade'] == 'buy ' + ticker:
            current = book.loc[i, 'Adj Close']
            rtn = (current - buy) / buy + 1
            book.loc[i, 'return'] = rtn
        elif book.loc[i, 'trade'] == '' and book.shift(1).loc[i, 'trade'] == 'buy ' + ticker:
            sell = book.loc[i, 'Adj Close']
            rtn = (sell - buy) / buy + 1
            book.loc[i, 'return'] = rtn
            print('청산일: ', i, ' 진입가격: ', buy, ' | long 청산가격: ', sell, 'return: ', round(rtn, 4))
        
        if book.loc[i, 'trade'] == '':
            buy = 0.0
            sell = 0.0
            current = 0.0
    
    acc_rtn = 1.0
    for i in book.index:
        if book.loc[i, 'trade'] == '' and book.shift(1).loc[i, 'trade'] == 'buy ' + ticker:
            rtn = book.loc[i, 'return']
            acc_rtn = acc_rtn * rtn
            book.loc[i, 'acc return'] = acc_rtn
    
    print('Accumulated return: ', round(acc_rtn, 4))
    return round(acc_rtn, 4)

print(returns(book, ticker))
# Out:
# 진입일:  2011-03-31 00:00:00  진입가격:  12.45
# 청산일:  2013-02-28 00:00:00  진입가격:  12.45  | long 청산가격:  15.76 return:  1.2659
# 진입일:  2013-12-31 00:00:00  진입가격:  20.04
# 청산일:  2016-01-29 00:00:00  진입가격:  20.04  | long 청산가격:  24.34 return:  1.2146
# 진입일:  2016-12-30 00:00:00  진입가격:  28.95
# 청산일:  2019-01-31 00:00:00  진입가격:  28.95  | long 청산가격:  41.61 return:  1.4373
# 진입일:  2019-03-29 00:00:00  진입가격:  47.49
# 청산일:  2019-06-28 00:00:00  진입가격:  47.49  | long 청산가격:  49.48 return:  1.0419
# 진입일:  2019-07-31 00:00:00  진입가격:  53.26
# 청산일:  2019-08-30 00:00:00  진입가격:  53.26  | long 청산가격:  52.19 return:  0.9799
# 진입일:  2019-10-31 00:00:00  진입가격:  62.19
# Accumulated return:  2.2562
# 2.2562
